# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/tanakajunta/dspro2-baseball/output.csv')

# %%
df.head()
# Out:
#    No    選手名        生年月日   身長   体重  投  打         備考
# 0  11     ケラ  1993.04.16  185   99  右  右  7/13 自由契約
# 1  12  石山　泰稚  1988.09.01  182   75  右  右        NaN
# 2  14  高梨　裕稔  1991.06.05  187   90  右  右        NaN
# 3  15   山下　輝  1999.09.12  188  100  左  左        NaN
# 4  16   原　樹理  1993.07.19  180   79  右  右        NaN

# %%
data = df
height = data['身長']
weight = data['体重']

# 散布図を作成
plt.scatter(height, weight,s=20 )
plt.scatter(176, 49)

# グラフにタイトルと軸ラベルを追加
plt.title('')
plt.xlabel('height (cm)')
plt.ylabel('weight (kg)')

# グラフを表示
plt.show()
